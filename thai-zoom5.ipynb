# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\IEC010240\Desktop\Thai_Tone\ZOOM0005.txt", encoding="UTF-8", sep="\t", header=0)
#df['tmin'] = df['tmin'].str.replace(" ", "")
#df['tmax'] = df['tmax'].str.replace(" ", "")
df['tier'] = df['tier'].str.replace(" ", "")
df['text'] = df['text'].str.replace(" ", "")
print(df)
# Out:
#              tmin     tier    text         tmax
# 0       32.105275     word       老    32.974001
# 1       32.105275  IU/tone      21    32.974001
# 2       32.105275  EU/tone      35    32.974001
# 3       35.714925  IU/tone    2155    36.483709
# 4       35.714925  EU/tone    2155    36.483709
# 5       35.714925     word      老師    36.483709
# 6       38.023245     word      老師    38.576770
# 7       38.023245  IU/tone    2155    38.576770
# 8       38.023245  EU/tone    2155    38.576770
# 9       38.576770     word       我    38.876595
# 10      38.576770  IU/tone      21    38.876595
# 11      38.576770  EU/tone      21    38.876595
# 12      38.876595     word       要    39.253300
# 13      38.876595  EU/tone      51    39.253300
# 14      38.876595  IU/tone      51    39.253300
# 15      39.253300  EU/tone    5521    40.421852
# 16      39.253300     word      喝水    40.421852
# 17      39.253300  IU/tone    5521    40.421852
# 18     137.425903     word      老師   138.263878
# 19     137.425903  IU/tone    2155   138.263878
# 20     137.425903  EU/tone    2155   138.263878
# 21     138.263878  IU/tone      21   138.579079
# 22     138.263878  EU/tone      21   138.579079
# 23     138.263878     word       我   138.579079
# 24     138.579079  EU/tone      51   139.024974
# 25     138.579079  IU/tone      51   139.024974
# 26     138.579079     word       要   139.024974
# 27     139.024974  EU/tone    5521   139.816822
# 28     139.024974  IU/tone    5521   139.816822
# 29     139.024974     word      喝水   139.816822
# ...           ...      ...     ...          ...
# 1275  1802.959556  EU/tone      35  1803.586007
# 1276  1802.959556  IU/tone      35  1803.586007
# 1277  1802.959556     word       我  1803.586007
# 1278  1803.586007  IU/tone    2151  1804.710538
# 1279  1803.586007     word      晚上  1804.710538
# 1280  1803.586007  EU/tone    2151  1804.710538
# 1281  1804.710538  EU/tone    3521  1805.609136
# 1282  1804.710538  IU/tone    3521  1805.609136
# 1283  1804.710538     word      洗澡  1805.609136
# 1284  1823.689152     word       我  1823.992108
# 1285  1823.689152  EU/tone      21  1823.992108
# 1286  1823.689152  IU/tone      21  1823.992108
# 1287  1823.992108  EU/tone      51  1824.151288
# 1288  1823.992108  IU/tone      51  1824.151288
# 1289  1823.992108     word       要  1824.151288
# 1290  1824.151288  EU/tone  515121  1824.921515
# 1291  1824.151288  IU/tone  515121  1824.921515
# 1292  1824.151288     word     上廁所  1824.921515
# 1293  1835.550193  EU/tone      51  1835.955846
# 1294  1835.550193     word       看  1835.955846
# 1295  1835.550193  IU/tone      51  1835.955846
# 1296  1835.955846     word      電視  1837.018759
# 1297  1835.955846  EU/tone    5151  1837.018759
# 1298  1835.955846  IU/tone    5151  1837.018759
# 1299  1838.716714     word       看  1839.271277
# 1300  1838.716714  EU/tone      51  1839.271277
# 1301  1838.716714  IU/tone      51  1839.271277
# 1302  1839.271277  IU/tone    5151  1840.565258
# 1303  1839.271277  EU/tone    5151  1840.565258
# 1304  1839.271277     word      電視  1840.565258
#
# [1305 rows x 4 columns]

# %%
column=['tmin','tmax','word','IU/tone','EU/tone']
newdf = pd.DataFrame(columns = column)
#print(newdf)
#print(int(df.shape[0]-1 / 3))

for i in range(df.shape[0]):
    tmin = df.iloc[i].tmin
    tmax = df.iloc[i].tmax
    r = newdf.loc[(newdf['tmax'] == tmax) & (newdf['tmin'] == tmin)]
    #print(r)
    if r.empty:
        s = pd.Series({'tmin':tmin, 'tmax':tmax})
        # 这里 Series 必须是 dict-like 类型
        newdf = newdf.append(s, ignore_index=True)    

for idxbase in range(df.shape[0]):
    tmin = df.iloc[idxbase].tmin
    tmax = df.iloc[idxbase].tmax

    if df.iloc[idxbase].tier =='word':
        word = df.iloc[idxbase].text
        newdf.loc[(newdf.tmax == tmax) & (newdf.tmin == tmin), 'word'] = word
    elif df.iloc[idxbase].tier =='IU/tone':
        if len(df.iloc[idxbase].text) <= 2 :
            iu = df.iloc[idxbase].text
        else:
            s = df.iloc[idxbase].text
            iu = " ".join(s[k:k+2] for k in range(0, len(s), 2))
        newdf.loc[(newdf.tmax == tmax) & (newdf.tmin == tmin), 'IU/tone'] = iu
    elif df.iloc[idxbase].tier =='EU/tone':
        #print("EU/tone", df.iloc[idxbase].tier)
        if len(df.iloc[idxbase].text) <= 2 :
            eu = df.iloc[idxbase].text
        else:
            s = df.iloc[idxbase].text
            eu = " ".join(s[k:k+2] for k in range(0, len(s), 2))
        newdf.loc[(newdf.tmax == tmax) & (newdf.tmin == tmin), 'EU/tone'] = eu

pd.set_option('display.width', 1000)
newdf.style.set_properties(**{'text-align': 'right'})
print(newdf)
# Out:
#             tmin         tmax word   IU/tone   EU/tone
# 0      32.105275    32.974001    老        21        35
# 1      35.714925    36.483709   老師     21 55     21 55
# 2      38.023245    38.576770   老師     21 55     21 55
# 3      38.576770    38.876595    我        21        21
# 4      38.876595    39.253300    要        51        51
# 5      39.253300    40.421852   喝水     55 21     55 21
# 6     137.425903   138.263878   老師     21 55     21 55
# 7     138.263878   138.579079    我        21        21
# 8     138.579079   139.024974    要        51        51
# 9     139.024974   139.816822   喝水     55 21     55 21
# 10    232.296737   233.215026   預備     51 51     21 51
# 11    233.646060   234.838465    二        51        51
# 12    236.750425   237.106776    九        21        21
# 13    237.716685   238.107300    八        55        55
# 14    239.997375   240.535210    六        51        51
# 15    240.932474   241.396968    五        21        21
# 16    241.917702   242.388308    四        51        51
# 17    244.490753   244.973582   十二     35 51     35 51
# 18    246.446516   246.819334    九        21        21
# 19    250.909001   251.322650    五        21        21
# 20    251.589375   251.987202    四        51        51
